# %%
import plotly.offline as pyo
import plotly_express as pyx
import plotly.graph_objects as go
import pandas as pd

data = pd.read_csv("sample_semanai.csv")

dato_hist = pyx.histogram(data, x="Clave platillo")
# dato_hist.show()

# stacked_bar = go.Figure(data=[
#     go.Bar(name="HAMBURGUESAS", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="ENTRADAS", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="BEBIDAS SIN ALCOHOL", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="BEBIDAS CON ALCOHOL", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="POSTRES", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="CLÁSICOS", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="PAPAS, PAPAS Y MÁS PAPAS", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="BÁSICOS", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="PASTAS", x=data["Día"], y=data["Grupo"]),
#     go.Bar(name="EXTRAS COCINA", x=data["Día"], y=data["Grupo"])
#     go.Bar(name="EXTRAS COCINA", x=data["Día"], y=data["Grupo"])
# ])

# stacked_bar.update_layout(barmode='stack')
# stacked_bar.show()


data_ham = data[data["Tipo de grupo"] == "Alimentos"]
ham_hist = pyx.histogram(data_ham, x="Clave platillo")
ham_hist.show()

data_bebidas = data[data["Tipo de grupo"] == "Bebidas"]
bebidas_hist = pyx.histogram(data_bebidas, x="Clave platillo")
bebidas_hist.show()
# Out:
# <div>
#
#
#             <div id="07356071-275e-4407-af58-6b18cede3712" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07356071-275e-4407-af58-6b18cede3712")) {
#                     Plotly.newPlot(
#                         '07356071-275e-4407-af58-6b18cede3712',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Clave platillo=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["ENT4", "MCL\u00c153", null, null, "MCL\u00c149", "MHAM30", "MCL\u00c132", "MHAM30", "HAM1", "MHAM29", "ENT1", "CLA2", "MHAM30", "MCL\u00c141", "ENT3", "MHAM31", "MHAM30", "MCL\u00c164", "SAN2", "MHAM30", "CLA1", "CLA1", "CLA1", "POS1", "PPP2", "PPP2", "PPP2", "ENT4", "MCL\u00c138", "CLA1", "MCL\u00c118", "PPP1", "MCL\u00c125", "MCL\u00c125", "HAM7", "MHAM30", "MHAM30", "EXT4614", "EXT4614", "EXT4614", "MHAM30", "MHAM30", "MHAM30", "HAM3", "MHAM30", "MHAM30", "HAM1", "MHAM30", "CLA1", "CLA1", "CLA1", "HAM12", "MHAM33", "HAM10", "MHAM30", "MHAM33", "MHAM33", "MCL\u00c157", "MCL\u00c154", "HAM12", "MHAM30", "PAS3", "PAS3", "MHAM30", "PAS3", "MHAM32", "MCL\u00c164", "MCL\u00c164", null, null, null, "MHAM30", "HAM11", "SAN1", "SAN1", "MHAM30", "MHAM30", "SAN3", "MHAM30", "SAN4", "MHAM30", "MHAM30", "MHAM30", "MHAM3", "HAM11", "HAM11", "SAN4", "MHAM30", "POS1", "POS1", "HAM12", "MHAM30", "MHAM30", "HAM12", "MHAM30", "MHAM30", "MHAM30", "MCL\u00c125", "CLA1", "MCL\u00c125", "MCL\u00c125", "MCL\u00c125", "MCL\u00c120", "HAM12", "MHAM30", "EXT4650", "EXT4613", "MCL\u00c142", "MCL\u00c142", "MCL\u00c142", "MCL\u00c155", "MCL\u00c155", "EXT0103", "HAM1", "MHAM30", "HAM12", "SAN1", "HAM7", "HAM7", "HAM7", "HAM7", "HAM7", "MHAM30", "HAM7", "MHAM30", "MHAM30", "HAM6", "MHAM30", "HAM10", "HAM10", "MHAM30", "MHAM30", "CLA1", "MCL\u00c122", null, "HAM12", "MHAM30", "HAM12", "MHAM30", "HAM7", "MHAM30", "HAM7", "HAM1", "HAM1", "HAM2", "CLA1", "CLA1", "MCL90001", "MCL90002", "MCL90002", "HAM7", "HAM7", "MHAM29", "HAM7", "HAM12", "HAM12", "HAM12", "HAM12", "MHAM30", "MHAM30", "POS2", "MPOS3", "MPOS3", "HAM1", "MHAM30", "PPP4", "HAM12", "MCL\u00c125", "ENT4", "ENT4", "MCL\u00c153", "MCL\u00c153", "MCL\u00c150", "MHAM29", "HAM3", "MHAM30", "MHAM30", "HAM7", "HAM12", "MHAM30", "HAM3", "MCL\u00c164", "MHAM30", "CLA1", null, "MHAM31", "ENS2", "MCL\u00c130", "SAN3", "SAN3", "MENS19", "HAM1", "HAM1", "HAM1", "PAS3", "MCL\u00c164", "CLA1", "MCL\u00c125", "HAM12", "HAM12", "CLA1", "ENT3", "HAM1", "HAM1", "HAM1", "MHAM30", "MHAM30", "MPAP1", "MCL\u00c154", "PAS2", "PAS2", "MHAM30", "MHAM30", "MHAM30", "MHAM30", "CLA1", "MCL90002", "HAM12", "HAM12", "MHAM30", "MHAM30", "MCL\u00c149", "MCL\u00c149", "MCL\u00c157", "MCL\u00c150", "ENT4", "MCL\u00c157", "MCL\u00c157", "MCL\u00c154", "MCL\u00c154", "CLA5", "MCL\u00c149", "MCL\u00c154", "MCL\u00c150", "MHAM30", "MCL\u00c154", "MCL\u00c154", "MCL\u00c150", "ENS4", "ENS4", "HAM8", "PPP1", "MHAM30", "HAM12", "ENS4", "SAN4", "HAM1", "CLA1", "HAM1", "ENS4", "MENS13", "ENT4", "MCL\u00c141", "MCL\u00c141", "MCL\u00c153", "MCL\u00c150", "MCL\u00c150", "POS3", "MPOS2", "ENT4", "MCL\u00c142", "POS1", "MCL\u00c149", "MCL\u00c154", "MCL\u00c150", "EXT4598", "EXT4598", "EXT4598", "HAM10", "MHAM30", "MHAM30", "MHAM30", "MHAM30", "MHAM32", "HAM12", "HAM12", "HAM12", "MHAM30", "HAM8", "MHAM30", "HAM7", "HAM12", "HAM12", "CLA1", "MCL\u00c125", "MCL\u00c154", "SAN1", "MHAM30", "HAM8", "MHAM30", "HAM1", "MHAM30", null, null, "HAM1", "MHAM30", "MHAM30", "HAM7", "MHAM30", "POS1", null, "PPP1", "EXT0103", "EXT0103", "MCL\u00c125", "ENT1", "ENT1", "ENT1", "ENT1", "MHAM30", "HAM1", "HAM1", "HAM1", "HAM1", "HAM1", "MHAM30", "MHAM30", "ENT1", "MENS19", "MHAM30", "MHAM30", "ENT1", "HAM