# %%
import plotly.offline as pyo
import plotly_express as pyx
import plotly.graph_objects as go
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import plotly.figure_factory as ff
import numpy as np
from numpy import *
import pandas as pd

data = pd.read_csv("sample_semanai.csv")
data = data.drop_duplicates().iloc[:]

# %%
def heatmap(x, y, size):
    fig, ax = plt.subplots()
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num), # Use mapping for x
        y=y.map(y_to_num), # Use mapping for y
        s=size * size_scale, # Vector of square sizes, proportional to size parameter
        marker='s' # Use square as scatterplot marker
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)
    
top_10 = data.groupby(['Clave platillo'])['Cantidad'].agg(
    {"Cuenta": len}).sort_values(
    "Cuenta", ascending=False).head(10).reset_index()
top_10 = top_10['Clave platillo']
data2 = data.groupby('Clave platillo')
data2.first()
# Out:
# c:\users\gtdav\miniconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning:
#
# using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#                 Unnamed: 0        Día  Orden  No. Personas    Terminal Acción  \
# Clave platillo
# BAS1                   138  miércoles      1            10  Terminal 1  Venta
# BAS10               130689    domingo    200             2  Terminal 3  Venta
# BAS11                35421    domingo      5             3  Terminal 3  Venta
# BAS12                 8035    domingo      4             3  Terminal 3  Venta
# BAS13                20779      lunes    103             2  Terminal 3  Venta
# ...                    ...        ...    ...           ...         ...    ...
# bebi03                4982    viernes    143             2  Terminal 1  Venta
# mcl90004             33698     sábado     69             9  Terminal 1  Venta
# mcl90005             46750     jueves     51            30  Terminal 1  Venta
# mcl90009             11096     jueves     21             3  Terminal 3  Venta
# mcla9006            113305    domingo    129             4  Terminal 1  Venta
#
#                 Cantidad Tipo de grupo                Grupo  \
# Clave platillo
# BAS1                 1.0       Bebidas              BÁSICOS
# BAS10                1.0       Bebidas              BÁSICOS
# BAS11                1.0       Bebidas              BÁSICOS
# BAS12                1.0       Bebidas              BÁSICOS
# BAS13                1.0       Bebidas              BÁSICOS
# ...                  ...           ...                  ...
# bebi03               1.0       Bebidas  BEBIDAS CON ALCOHOL
# mcl90004             1.0     Alimentos             CLÁSICOS
# mcl90005             1.0     Alimentos             CLÁSICOS
# mcl90009             1.0     Alimentos             CLÁSICOS
# mcla9006             1.0     Alimentos             CLÁSICOS
#
#                       Modificador  ... idEncuesta  cuenta  mesa  \
# Clave platillo                     ...
# BAS1                          NaN  ...     119407       1    32
# BAS10                         NaN  ...     382251     200    30
# BAS11                         NaN  ...     174254       5    50
# BAS12                         NaN  ...     125482       4    21
# BAS13                         NaN  ...     152280     103    71
# ...                           ...  ...        ...     ...   ...
# bebi03          Modelo Especial..  ...     122884     143    91
# mcl90004          BS Salsa aparte  ...     172614      69    80
# mcl90005             AL Sin Salsa  ...     195954      51   110
# mcl90009          AS Salsa aparte  ...     131232      21    71
# mcla9006          AL Salsa aparte  ...     352276     129    41
#
#                 recomendacion  El día de hoy ¿Con quién nos visita?  \
# Clave platillo
# BAS1                        1                                  Solo
# BAS10                       1                                Pareja
# BAS11                       1                                Pareja
# BAS12                       1                                Amigos
# BAS13                       1                                Amigos
# ...                       ...                                   ...
# bebi03                      1                               Familia
# mcl90004                    1                               Familia
# mcl90005                    1                               Familia
# mcl90009                    1                       Los del Trabajo
# mcla9006                    1                                Amigos
#
#                ¿Cuál es el rango de edades en tu mesa?  \
# Clave platillo
# BAS1                                           22 a 25
# BAS10                                          26 a 32
# BAS11                                          18 a 21
# BAS12                                          33 a 44
# BAS13                                          18 a 21
# ...                                                ...
# bebi03                                         26 a 32
# mcl90004                                       22 a 25
# mcl90005                                       18 a 21
# mcl90009                                       26 a 32
# mcla9006                                       22 a 25
#
#                 ¿De qué manera nos conocieron?  \
# Clave platillo
# BAS1            Redes Sociales del Restaurante
# BAS10                                    Plaza
# BAS11           Redes Sociales del Restaurante
# BAS12           Redes Sociales del Restaurante
# BAS13                                    Plaza
# ...                                        ...
# bebi03                           Recomendación
# mcl90004                                 Plaza
# mcl90005                         Recomendación
# mcl90009                                 Plaza
# mcla9006                            Influencer
#
#                ¿El gerente/capitán visitó tu mesa?  \
# Clave platillo
# BAS1                                           0.0
# BAS10                                          0.0
# BAS11                                          0.0
# BAS12                                          1.0
# BAS13                                          0.0
# ...                                            ...
# bebi03                                         1.0
# mcl90004                                       0.0
# mcl90005                                       1.0
# mcl90009                                       1.0
# mcla9006                                       0.0
#
#                 ¿Es la primera vez que nos visita en esta sucursal?  \
# Clave platillo
# BAS1                                                          0.0
# BAS10                                                         1.0
# BAS11                                                         1.0
# BAS12                                                         1.0
# BAS13                                                         0.0
# ...                                                           ...
# bebi03                                                        1.0
# mcl90004                                                      0.0
# mcl90005                                                      1.0
# mcl90009                                                      1.0
# mcla9006                                                      1.0
#
#                 ¿Por qué razón nos prefiere?
# Clave platillo
# BAS1                                 Calidad
# BAS10                                  Sabor
# BAS11                                  Sabor
# BAS12                                Calidad
# BAS13                                   Otro
# ...                                      ...
# bebi03                             Ubicación
# mcl90004                             Calidad
# mcl90005                             Calidad
# mcl90009                               Sabor
# mcla9006                               Sabor
#
# [354 rows x 21 columns]

# %%
data2 = data[data["Acción"] != "Cancelación"]
data2.dropna(axis=0, subset=['Clave platillo'], inplace=True)
corr = data2[top_10].corr()
corr = pd.melt(corr.reset_index(), id_vars='index')
corr.columns = ['x', 'y', 'value']
heatmap(
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)
