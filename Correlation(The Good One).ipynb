# %%
import plotly.offline as pyo
import plotly_express as pyx
import plotly.graph_objects as go
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import plotly.figure_factory as ff
import numpy as np
from numpy import *
import pandas as pd

data = pd.read_csv("sample_semanai.csv")
data = data.drop_duplicates().iloc[:]

# %%
def heatmap(x, y, size):
    fig, ax = plt.subplots()
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num), # Use mapping for x
        y=y.map(y_to_num), # Use mapping for y
        s=size * size_scale, # Vector of square sizes, proportional to size parameter
        marker='s' # Use square as scatterplot marker
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)
    
#top_10 = data.groupby(['Clave platillo'])['Cantidad'].agg(
#    {"Cuenta": len}).sort_values(
#    "Cuenta", ascending=False).head(10).reset_index()
#top_10 = top_10['Clave platillo']

data['TipoDia'] = 0
for i, row in data.iterrows():
    if data["Día"][i] == 'lunes':
        data["TipoDia"][i] = 1
    elif data["Día"][i] == 'martes':
        data["TipoDia"][i] = 2
    elif data["Día"][i] == 'miércoles':
        data["TipoDia"][i] = 3
    elif data["Día"][i] == 'jueves':
        data["TipoDia"][i] = 4
    elif data["Día"][i] == 'viernes':
        data["TipoDia"][i] = 5
    elif data["Día"][i] == 'sábado':
        data["TipoDia"][i] = 6
    else data["Día"][i] == 'domingo':
        data["TipoDia"][i] = 7
data
# Out:
#   File "<ipython-input-23-116a94ae35fc>", line 43
#     else data["Día"][i] == 'domingo':
#             ^
# SyntaxError: invalid syntax

# %%
data2 = data[data["Acción"] != "Cancelación"]
data2.dropna(axis=0, subset=['Clave platillo'], inplace=True)
data2 = data2[[]]
corr = data[top_10].corr()
#corr = pd.melt(corr.reset_index(), id_vars='index')
#corr.columns = ['x', 'y', 'value']
#heatmap(
#    x=corr['x'],
#    y=corr['y'],
#    size=corr['value'].abs()
#)
data.corr(method='pearson')
# Out:
#                                                     Unnamed: 0     Orden  \
# Unnamed: 0                                            1.000000 -0.028709
# Orden                                                -0.028709  1.000000
# No. Personas                                         -0.041924 -0.078226
# Cantidad                                              0.012633 -0.003439
# idEncuesta                                            0.993879 -0.028266
# cuenta                                               -0.028709  1.000000
# mesa                                                 -0.030943  0.001158
# recomendacion                                         0.001787 -0.018899
# ¿El gerente/capitán visitó tu mesa?                  -0.180417  0.048650
# ¿Es la primera vez que nos visita en esta sucur...    0.013592  0.016833
#
#                                                     No. Personas  Cantidad  \
# Unnamed: 0                                             -0.041924  0.012633
# Orden                                                  -0.078226 -0.003439
# No. Personas                                            1.000000  0.037447
# Cantidad                                                0.037447  1.000000
# idEncuesta                                             -0.039306  0.013697
# cuenta                                                 -0.078226 -0.003439
# mesa                                                    0.023832 -0.001567
# recomendacion                                          -0.007262  0.007131
# ¿El gerente/capitán visitó tu mesa?                     0.002894  0.000586
# ¿Es la primera vez que nos visita en esta sucur...      0.013363 -0.004481
#
#                                                     idEncuesta    cuenta  \
# Unnamed: 0                                            0.993879 -0.028709
# Orden                                                -0.028266  1.000000
# No. Personas                                         -0.039306 -0.078226
# Cantidad                                              0.013697 -0.003439
# idEncuesta                                            1.000000 -0.028266
# cuenta                                               -0.028266  1.000000
# mesa                                                 -0.031110  0.001158
# recomendacion                                         0.001799 -0.018899
# ¿El gerente/capitán visitó tu mesa?                  -0.178145  0.048650
# ¿Es la primera vez que nos visita en esta sucur...    0.014696  0.016833
#
#                                                         mesa  recomendacion  \
# Unnamed: 0                                         -0.030943       0.001787
# Orden                                               0.001158      -0.018899
# No. Personas                                        0.023832      -0.007262
# Cantidad                                           -0.001567       0.007131
# idEncuesta                                         -0.031110       0.001799
# cuenta                                              0.001158      -0.018899
# mesa                                                1.000000       0.002370
# recomendacion                                       0.002370       1.000000
# ¿El gerente/capitán visitó tu mesa?                -0.012333       0.028176
# ¿Es la primera vez que nos visita en esta sucur... -0.011670      -0.020939
#
#                                                     ¿El gerente/capitán visitó tu mesa?  \
# Unnamed: 0                                                                    -0.180417
# Orden                                                                          0.048650
# No. Personas                                                                   0.002894
# Cantidad                                                                       0.000586
# idEncuesta                                                                    -0.178145
# cuenta                                                                         0.048650
# mesa                                                                          -0.012333
# recomendacion                                                                  0.028176
# ¿El gerente/capitán visitó tu mesa?                                            1.000000
# ¿Es la primera vez que nos visita en esta sucur...                             0.109993
#
#                                                     ¿Es la primera vez que nos visita en esta sucursal?
# Unnamed: 0                                                                                   0.013592
# Orden                                                                                        0.016833
# No. Personas                                                                                 0.013363
# Cantidad                                                                                    -0.004481
# idEncuesta                                                                                   0.014696
# cuenta                                                                                       0.016833
# mesa                                                                                        -0.011670
# recomendacion                                                                               -0.020939
# ¿El gerente/capitán visitó tu mesa?                                                          0.109993
# ¿Es la primera vez que nos visita en esta sucur...                                           1.000000
